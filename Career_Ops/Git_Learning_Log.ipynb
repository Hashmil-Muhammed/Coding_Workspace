# %% [markdown]
# # Git & Version Control - Learning Log

# %% [markdown]
# ## Git Initialization & Initial Commit
# * **Date:** June 16, 2026
# * **Status:** Initialized local repository and pushed to GitHub main branch.

# %% [markdown]
# ### Commands Executed:

# %% [markdown]
# 1. **Initialization:**
#
#    `git init` - Created a new empty Git repository in the local workspace.

# %% [markdown]
# 2. **Configuration:**
#
#     `git config --global user.name "Hashmil Muhammed"` <br>
#     `git config --global user.email "hashmilmuhammedparammal@gmail.com"`

# %% [markdown]
# 3. **Staging & Committing:**
#    - Staged files using `git add .` (Added 8 files including Notebooks and Roadmap).
#    - Committed changes using `git commit -m "Day 2: Data & ML Mastery - NumPy Pandas practice"`.

# %% [markdown]
# 4. **Remote Repository Setup:**
#    - Added remote origin: `https://github.com/Hashmil-Muhammed/Coding_Workspace.git`
#    - Renamed default branch to `main`: `git branch -M main`
#    - Pushed code to GitHub: `git push -u origin main`

# %% [markdown]
# ### Key Takeaways:
# * Version control is essential for tracking AI/ML project progress.
# * `git status` helps in checking which files are modified or untracked before committing.
# * Pushing to GitHub ensures that code is backed up and accessible from anywhere.

# %% [markdown]
# ### 📝 Daily Git Workflow (Routine)
# To maintain your repository efficiently, execute these commands in your terminal at the end of every study session:
#
#
# 1. **Stage all changes (new files, modified files, etc.)**
#
#     `git add .`
#
# 2. **Commit your progress with a descriptive message**
# (Replace 'X' with the current day and '[task]' with what you worked on)
#
#     `git commit -m "Day X: [Your task description]"`
#
# 3. **Push your committed changes to GitHub**
#
#     `git push`
